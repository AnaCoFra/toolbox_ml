# %%
import sys
from pathlib import Path

# subir al directorio raíz del repo
sys.path.append(str(Path.cwd().parent))

from toolbox_ml.eda.core_describe_tipifica import describe_df, tipifica_variables
import pandas as pd

df = pd.read_csv("data/titanic.csv")  
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
display(describe_df(df))
# Out:
#                 tipo  porcentaje_nulos  valores_unicos  \
# survived       int64          0.000000               2
# pclass         int64          0.000000               3
# sex           object          0.000000               2
# age          float64         19.865320              88
# sibsp          int64          0.000000               7
# parch          int64          0.000000               7
# fare         float64          0.000000             248
# embarked      object          0.224467               3
# class         object          0.000000               3
# who           object          0.000000               3
# adult_male      bool          0.000000               2
# deck          object         77.216611               7
# embark_town   object          0.224467               3
# alive         object          0.000000               2
# alone           bool          0.000000               2
#
#              porcentaje_cardinalidad
# survived                    0.224467
# ...

# %%
tipifica_variables(df, umbral_categorica=10, umbral_continua=0.5)
# Out:
#    Nombre variable      Tipo sugerido
# 0         survived            Binaria
# 1           pclass         Categorica
# 2              sex            Binaria
# 3              age  Numérica Discreta
# 4            sibsp         Categorica
# 5            parch         Categorica
# 6             fare  Numérica Discreta
# 7         embarked         Categorica
# 8            class         Categorica
# 9              who         Categorica
# 10      adult_male            Binaria
# 11            deck         Categorica
# 12     embark_town         Categorica
# 13           alive            Binaria
# 14           alone            Binaria
